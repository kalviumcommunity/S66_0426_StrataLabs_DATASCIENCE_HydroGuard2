# %% [markdown]
# # Unit 4.16: Conditional Data Logic
#
# Use if/elif/else to convert rainfall totals into risk levels.

# %%
monsoon_total = 1085
if monsoon_total >= 1100:
    risk = 'High'
elif monsoon_total >= 900:
    risk = 'Medium'
else:
    risk = 'Low'
risk
