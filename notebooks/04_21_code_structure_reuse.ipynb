# %% [markdown]
# # Unit 4.21: Structuring Code for Readability and Reuse
#
# Split loading, computation, and reporting into separate functions for maintainable pipelines.

# %%
from pathlib import Path
Path('../outputs/reports/structured_pipeline_demo.md').exists()
