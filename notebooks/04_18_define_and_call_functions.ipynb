# %% [markdown]
# # Unit 4.18: Defining and Calling Functions
#
# Functions help package reusable rainfall logic into clear blocks.

# %%
def monsoon_total(jun, jul, aug, sep):
    return jun + jul + aug + sep

monsoon_total(210, 320, 295, 260)
