# %% [markdown]
# # Unit 4.35: Identifying and Removing Duplicate Records
#
# Detect duplicates with `duplicated()` and clean using `drop_duplicates()`.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/rainfall_sample_processed.csv')
dup_df = pd.concat([df, df.iloc[[0]]], ignore_index=True)
dup_df.duplicated().sum(), dup_df.drop_duplicates().shape
