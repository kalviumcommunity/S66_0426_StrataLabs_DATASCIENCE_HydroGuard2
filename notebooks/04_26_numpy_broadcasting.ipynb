# %% [markdown]
# # Unit 4.26: NumPy Broadcasting
#
# Apply row-wise operations with smaller arrays automatically expanded by NumPy.

# %%
import numpy as np
matrix = np.array([[210, 320, 295, 260], [155, 248, 232, 201]])
offsets = np.array([5, -10, 8, 3])
matrix + offsets
