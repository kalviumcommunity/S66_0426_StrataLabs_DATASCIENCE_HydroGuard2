# %% [markdown]
# # Unit 4.24: Basic Mathematical Operations on NumPy Arrays
#
# Apply addition, multiplication, and element-wise operations directly on arrays.

# %%
import numpy as np
a = np.array([210, 320, 295, 260])
b = np.array([155, 248, 232, 201])
a + 10, a * 1.05, a + b
