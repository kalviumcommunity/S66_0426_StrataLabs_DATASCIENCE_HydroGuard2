# %% [markdown]
# # Unit 4.15: Lists, Tuples, and Dictionaries
#
# These structures represent rainfall months, records, and district summaries.

# %%
months = ("jun", "jul", "aug", "sep")
records = [{"district": "coastal_north", "total": 1085}, {"district": "delta_west", "total": 881}]
summary = {record['district']: record['total'] for record in records}
months, summary
