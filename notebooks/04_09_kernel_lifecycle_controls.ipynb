# %% [markdown]
# # Unit 4.9: Kernel Lifecycle Controls
#
# This notebook demonstrates when to run, interrupt, and restart kernels during data analysis.

# %% [markdown]
# ## Key Rules
# - Run cells top-to-bottom when state matters
# - Interrupt when a cell hangs
# - Restart kernel when variables are stale or inconsistent
# - Re-run all cells after restart for reproducibility

# %%
import time
for step in range(5):
    print(f'processing step {step + 1}')
    time.sleep(1)

# %%
# After a kernel restart, run this cell again to restore state
baseline_threshold = 0.75
baseline_threshold
