# %% [markdown]
# # Unit 4.10: Notebook Markdown Patterns
#
# This notebook demonstrates headings, lists, and code blocks for analysis documentation.

# %% [markdown]
# ## Flood-Risk Notes
# ### Assumptions
# - Rainfall is measured in millimeters.
# - Monsoon months are June to September.
#
# ### Data Quality Checklist
# 1. Detect missing values
# 2. Remove duplicates
# 3. Validate numeric columns

# %% [markdown]
# ## Example Code Block
# ```python
# def rainfall_anomaly(current, baseline):
#     return current - baseline
# ```

# %%
def rainfall_anomaly(current, baseline):
    return current - baseline

rainfall_anomaly(1450, 1320)
