# %% [markdown]
# # Unit 4.32: Selecting Rows and Columns Using Indexing and Slicing
#
# Use `.loc` and `.iloc` to select specific rows and columns safely.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/rainfall_sample_processed.csv')
df.loc[:, ['district', 'monsoon_total']].head(2), df.iloc[0:2, :]
