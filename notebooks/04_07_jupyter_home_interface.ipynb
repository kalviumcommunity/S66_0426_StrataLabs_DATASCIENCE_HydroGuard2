# %% [markdown]
# # Unit 4.7: Jupyter Home Interface
#
# This notebook captures what to check on the Jupyter home screen before analysis work starts.

# %% [markdown]
# ## Home Interface Checklist
# - Confirm current working directory is the project `notebooks/` folder
# - Verify files panel lists notebooks and data folders
# - Use **New** to create Python notebooks for each learning unit
# - Use **Upload** only for approved raw datasets

# %%
from pathlib import Path
Path.cwd()
