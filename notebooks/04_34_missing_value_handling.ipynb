# %% [markdown]
# # Unit 4.34: Handling Missing Values with Drop and Fill
#
# Apply dropna and fillna strategies based on analysis goals.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/rainfall_sample_processed.csv')
df.loc[0, 'aug'] = None
df.dropna().shape, df['aug'].fillna(df['aug'].mean()).isna().sum()
