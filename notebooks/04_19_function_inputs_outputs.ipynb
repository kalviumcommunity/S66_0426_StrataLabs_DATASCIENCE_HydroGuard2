# %% [markdown]
# # Unit 4.19: Function Inputs and Return Values
#
# Pass rainfall values into functions and return computed metrics.

# %%
def rainfall_anomaly(current_total, baseline_total):
    return current_total - baseline_total

rainfall_anomaly(1147, 1038.5)
