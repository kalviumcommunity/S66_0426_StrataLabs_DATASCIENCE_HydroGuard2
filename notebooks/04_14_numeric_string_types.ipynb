# %% [markdown]
# # Unit 4.14: Python Numeric and String Types
#
# Use strings for ingestion and numeric types for calculations in rainfall workflows.

# %%
district = "Coastal North"
rainfall_text = "322.5"
rainfall_mm = float(rainfall_text)
type(district).__name__, type(rainfall_mm).__name__
