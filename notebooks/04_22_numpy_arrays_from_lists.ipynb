# %% [markdown]
# # Unit 4.22: Creating NumPy Arrays from Python Lists
#
# Convert list-based rainfall values into NumPy arrays for numerical workflows.

# %%
import numpy as np
values = [210, 320, 295, 260]
array_values = np.array(values)
array_values, array_values.dtype
