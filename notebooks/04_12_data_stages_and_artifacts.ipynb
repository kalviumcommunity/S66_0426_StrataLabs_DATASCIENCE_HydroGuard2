# %% [markdown]
# # Unit 4.12: Raw, Processed, and Output Artifacts
#
# This notebook documents where each data stage should be stored in the HydroGuard workflow.

# %% [markdown]
# ## Stage Rules
# - `data/raw`: original files, no manual edits
# - `data/processed`: cleaned, transformed, and feature-ready files
# - `outputs/reports`, `outputs/figures`, `outputs/models`: generated artifacts

# %%
from pathlib import Path
sorted(str(p.relative_to('..')) for p in Path('..').glob('outputs/*'))
