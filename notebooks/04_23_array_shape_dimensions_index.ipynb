# %% [markdown]
# # Unit 4.23: Array Shape, Dimensions, and Index Positions
#
# Understand how NumPy arrays are structured and accessed by position.

# %%
import numpy as np
matrix = np.array([[210, 320, 295, 260], [155, 248, 232, 201]])
matrix.shape, matrix.ndim, matrix[0, 2]
