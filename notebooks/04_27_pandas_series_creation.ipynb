# %% [markdown]
# # Unit 4.27: Creating Pandas Series from Lists and Arrays
#
# Create labeled 1D pandas structures from list and NumPy sources.

# %%
import numpy as np
import pandas as pd
series_list = pd.Series([1085, 1147, 836], name='from_list')
series_array = pd.Series(np.array([881, 752, 924]), name='from_array')
series_list.tolist(), series_array.tolist()
