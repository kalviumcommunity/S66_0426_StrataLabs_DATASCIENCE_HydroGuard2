# %% [markdown]
# # Unit 4.31: DataFrame Shape and Column Data Types
#
# Inspect shape and dtypes before analysis to avoid schema-related errors.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/rainfall_sample_processed.csv')
df.shape, df.dtypes
