# %% [markdown]
# # Unit 4.30: Inspecting DataFrames with head(), info(), and describe()
#
# Use quick inspection methods to understand data structure before analysis.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/rainfall_sample_processed.csv')
df.head(2), df.describe()
