# %% [markdown]
# # Unit 4.38: Comparing Distributions Across Multiple Columns
#
# Compare mean, spread, and range across multiple rainfall columns.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/rainfall_sample_processed.csv')
df[['jun', 'jul', 'aug', 'sep', 'monsoon_total']].describe().T
