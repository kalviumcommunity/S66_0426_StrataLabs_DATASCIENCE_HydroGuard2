# %% [markdown]
# # Unit 4.42: Exploring Relationships Using Scatter Plots
#
# Use scatter plots to inspect relationships between numeric variables.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../data/processed/rainfall_sample_processed.csv')
df.plot(kind='scatter', x='jun', y='monsoon_total', figsize=(7, 4))
plt.show()
