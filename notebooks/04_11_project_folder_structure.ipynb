# %% [markdown]
# # Unit 4.11: Project Folder Structure
#
# This notebook explains the baseline folder layout for reproducible data science work in HydroGuard.

# %% [markdown]
# ## Folder Layout
# - `data/raw`: immutable source datasets
# - `data/processed`: cleaned and engineered datasets
# - `notebooks`: exploratory and unit notebooks
# - `scripts`: utility scripts and environment checks
# - `src`: reusable package code
# - `outputs`: generated reports and artifacts

# %%
from pathlib import Path
sorted([p.name for p in Path('..').iterdir() if p.is_dir()])
