# %% [markdown]
# # Unit 4.13: First Python Data Analysis Script
#
# This notebook explains the first standalone script-based analysis workflow.

# %% [markdown]
# ## Script Goal
# - Load processed rainfall data
# - Compute baseline monsoon summary statistics
# - Generate markdown report under `outputs/reports`

# %%
from pathlib import Path
Path('../outputs/reports/first_analysis_summary.md').exists()
