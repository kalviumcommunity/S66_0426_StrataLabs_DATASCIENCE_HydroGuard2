# %% [markdown]
# # Unit 4.20: Readable Names and PEP 8 Basics
#
# Use clear snake_case variable names and concise comments when intent is not obvious.

# %%
district_name = 'coastal_north'
monsoon_total_mm = 1147
monsoon_total_cm = monsoon_total_mm / 10
district_name, monsoon_total_cm
