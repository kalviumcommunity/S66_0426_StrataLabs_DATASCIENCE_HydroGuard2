# %% [markdown]
# # Unit 4.28: Creating Pandas DataFrames from Dictionaries and Files
#
# Build DataFrames from in-memory dictionaries and external CSV sources.

# %%
import pandas as pd
dict_df = pd.DataFrame({'district': ['coastal_north', 'delta_west'], 'total': [1147, 881]})
file_df = pd.read_csv('../data/processed/rainfall_sample_processed.csv')
dict_df.shape, file_df.shape
