# %% [markdown]
# # Unit 4.29: Loading CSV Data into Pandas DataFrames
#
# Load processed rainfall CSV files with default and explicit dtype strategies.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/rainfall_sample_processed.csv')
df.shape, list(df.columns)
