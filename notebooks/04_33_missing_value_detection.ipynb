# %% [markdown]
# # Unit 4.33: Detecting Missing Values in DataFrames
#
# Use `isna()` patterns to identify missing values and affected rows.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/rainfall_sample_processed.csv')
df.loc[1, 'aug'] = None
df.isna().sum()
