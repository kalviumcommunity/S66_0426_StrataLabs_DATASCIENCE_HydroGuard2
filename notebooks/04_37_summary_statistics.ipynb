# %% [markdown]
# # Unit 4.37: Summary Statistics for Individual Columns
#
# Compute and interpret key summary statistics for a single numeric feature.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/rainfall_sample_processed.csv')
df['monsoon_total'].describe()
