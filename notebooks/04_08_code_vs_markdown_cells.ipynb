# %% [markdown]
# # Unit 4.8: Code Cells vs Markdown Cells
#
# Use markdown cells for explanation and code cells for execution.

# %% [markdown]
# ## Markdown Cell Purpose
# - Explain assumptions
# - Describe transformation intent
# - Document expected outputs

# %%
rainfall_mm = [110, 142, 98, 175]
avg_rainfall = sum(rainfall_mm) / len(rainfall_mm)
avg_rainfall

# %% [markdown]
# ## Code Cell Purpose
# Run logic that can be validated and reused in the flood-risk pipeline.
