# %% [markdown]
# # Unit 4.25: Vectorized Operations Instead of Python Loops
#
# Use NumPy vectorization for concise and scalable numeric transformations.

# %%
import numpy as np
values = np.array([1085, 1147, 836, 881], dtype=float)
baseline = values.mean()
values - baseline
